# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import os

# %%
# import parquet file src/output/all_data.parquet

data = pd.read_parquet('src/output/all_data.parquet')

# %%
data.head()
# Out:
#               ^GDAXI     ^GSPC     ^IXIC  unemployment  gdp  inflation  \
# 2006-01-02 -1.247425       NaN       NaN           NaN  NaN        NaN
# 2006-01-03 -1.243457 -0.840025 -0.884245           NaN  NaN        NaN
# 2006-01-04 -1.220116 -0.833331 -0.876285           NaN  NaN        NaN
# 2006-01-05 -1.222745 -0.833303 -0.870872           NaN  NaN        NaN
# 2006-01-06 -1.215406 -0.816110 -0.859268           NaN  NaN        NaN
#
#             interest_rate  money_supply      AAPL      MSFT      GOOG  \
# 2006-01-02            NaN        6696.8       NaN       NaN       NaN
# 2006-01-03            NaN           NaN -0.895238 -0.674184 -0.924353
# 2006-01-04            NaN           NaN -0.894965 -0.672271 -0.911999
# 2006-01-05            NaN           NaN -0.895697 -0.671976 -0.904594
# 2006-01-06            NaN           NaN -0.893317 -0.673154 -0.886798
#
#                 AMZN  FB  TSLA
# 2006-01-02       NaN NaN   NaN
# 2006-01-03 -0.766531 NaN   NaN
# ...

# %%
# descriptive statistics of the data
data.describe()
# Out:
#              ^GDAXI         ^GSPC         ^IXIC  unemployment           gdp  \
# count  3.800000e+03  3.776000e+03  3.776000e+03    181.000000     61.000000
# mean  -1.196704e-16 -6.021549e-17  1.806465e-16      6.307735  17296.113410
# std    1.000132e+00  1.000132e+00  1.000132e+00      2.209763   2583.329516
# min   -1.908864e+00 -1.690731e+00 -1.277825e+00      3.500000  13599.160000
# 25%   -8.908454e-01 -7.943955e-01 -8.003327e-01      4.600000  14865.701000
# 50%   -2.146366e-01 -2.917846e-01 -3.781072e-01      5.600000  16911.068000
# 75%    9.794692e-01  7.331730e-01  5.832394e-01      8.200000  19304.506000
# max    1.845587e+00  2.732564e+00  3.416720e+00     14.700000  22313.850000
#
#         inflation  interest_rate  money_supply          AAPL          MSFT  \
# count  181.000000     181.000000    783.000000  3.776000e+03  3.776000e+03
# mean   231.420387       1.232265  11027.037292  6.021549e-17 -6.021549e-17
# ...
